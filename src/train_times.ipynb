# %%
import matplotlib.pyplot as plt

# Data: Subjects and their corresponding accuracies
subjects = ['S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'S10', 'S11', 'S13', 'S14', 'S15', 'S16', 'S17']

# Decision Tree Accuracies
decision_tree_accuracies = [
    0.5097851417794841, 
    0.30316804772953265, 
    0.30082263225164485, 
    0.5845924350795799, 
    0.29331451926819774, 
    0.31022922772050715, 
    0.30156845474258215, 
    0.5793035958124716, 
    0.6133866616475312, 
    0.17249743523980507, 
    0.5300991335520899, 
    0.3752566712061895, 
    0.37763354871729254, 
    0.26827988146917, 
    0.6431829023349235
]
# XGBoost Accuracies
xg = [
    0.51,
    0.57,
    0.56,
    0.49,
    0.66,
    0.29,
    0.63,
    0.50,
    0.52,
    0.72,
    0.51,
    0.42,
    0.89,
    0.78,
    0.83 
]

dt_tuned = [
    0.47050313194584,
    0.5290023201856149,
    0.5348732861278218,
    0.5403698691926027,
    0.5358764759309719,
    0.5395810869744657,
    0.5291990746938334,
    0.537096040054,
    0.6333904259991217,
    0.7018248268786869,
    0.5300991335520899,
    0.6232871747468248,
    0.3072100313479624,
    0.2973948045315466,
    0.5188927943760984 
]
# LSTM Accuracies
lstm_accuracies = [
    0.67, 
    0.70, 
    0.67, 
    0.86, 
    0.46, 
    0.67, 
    0.71, 
    0.78, 
    0.82, 
    0.69, 
    0.70, 
    0.54, 
    0.55, 
    0.66, 
    0.67
]

# Create the line graph
plt.figure(figsize=(10, 6))

# Plot Decision Tree accuracies
plt.plot(subjects, decision_tree_accuracies, marker='o', label='Decision Tree (Baseline, Wrist)', color='blue')

# Plot LSTM accuracies
plt.plot(subjects, lstm_accuracies, marker='o', label='LSTM (Chest)', color='orange')

# Plot xg accuracies
plt.plot(subjects, xg, marker='o', label='XGBoost', color='red')

# Plot xg accuracies
plt.plot(subjects, dt_tuned, marker='o', label='Decision Tree (Tuned, Wrist)', color='violet')


# Adding titles and labels
plt.title('Model Accuracies by Subject')
plt.xlabel('Subjects')
plt.ylabel('Accuracy')
plt.xticks(rotation=45)
plt.grid(True)
plt.ylim(0, 1)  # Set y-axis limits to show accuracies as a percentage
# plt.axhline(y=0.5, color='r', linestyle='--', label='50% Threshold')
plt.legend()
plt.tight_layout()

# Show the graph
plt.show()

# %%
# Re-importing necessary libraries due to reset

import matplotlib.pyplot as plt

# Accuracy values for each model type
subjects = ['S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'S10', 'S11', 'S13', 'S14', 'S15', 'S16', 'S17']

# Decision Tree accuracies (redefining due to reset)
accuracy_chest_dt = {
    'S2': 0.6121674412339193, 'S3': 0.5604381836261186, 'S4': 0.5348739459756212, 'S5': 0.5753444165216831,
    'S6': 0.8968470221876217, 'S7': 0.4604189130255342, 'S8': 0.773042600428507, 'S9': 0.550200923337018,
    'S10': 0.6710094736181693, 'S11': 0.7940939984611439, 'S13': 0.9993890390264157, 'S14': 0.95916738779435,
    'S15': 0.8648263066982279, 'S16': 0.894772692627071, 'S17': 0.8229299522972634
}
accuracy_wrist_dt = {
    'S2': 0.5090530073415505, 'S3': 0.6060238647663242, 'S4': 0.8347430981569791, 'S5': 0.6926361234615632,
    'S6': 0.5997962890878422, 'S7': 0.5395810869744657, 'S8': 0.8172352177683617, 'S9': 0.9669035698029781,
    'S10': 0.7553510257858084, 'S11': 0.18693254680687355, 'S13': 0.6285832187246703, 'S14': 0.5642019602271087,
    'S15': 0.735409762651142, 'S16': 0.3157874086399893, 'S17': 0.8250213406979664
}

# XGBoost accuracies
accuracy_chest_xgb = {
    'S2': 0.5391627938304034, 'S3': 0.8254670202187604, 'S4': 0.6986527887477475, 'S5': 0.557086152458277,
    'S6': 0.9010496950823926, 'S7': 0.4604189130255342, 'S8': 0.6143947580642554, 'S9': 0.8894726575199948,
    'S10': 0.6484942593638245, 'S11': 0.5368158502180046, 'S13': 0.5301151776953037, 'S14': 0.9544416226559609,
    'S15': 0.8999373040752351, 'S16': 0.687368825259648, 'S17': 0.7605203364298267
}
accuracy_wrist_xgb = {
    'S2': 0.5393682225365394, 'S3': 0.5921146834603911, 'S4': 0.7398668823049276, 'S5': 0.7724196146658934,
    'S6': 0.6561813935383418, 'S7': 0.5395810869744657, 'S8': 0.7050867911057305, 'S9': 0.9598016776123285,
    'S10': 0.6967908902691511, 'S11': 0.9926199025391126, 'S13': 0.6009378764357102, 'S14': 0.5788674200606709,
    'S15': 0.5261979399910435, 'S16': 0.3862279628044235, 'S17': 0.7175822244539292
}

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(subjects, list(accuracy_chest_dt.values()), marker='o', label='Decision Tree - Chest')
plt.plot(subjects, list(accuracy_wrist_dt.values()), marker='o', label='Decision Tree - Wrist')
plt.plot(subjects, list(accuracy_chest_xgb.values()), marker='s', label='XGBoost - Chest')
plt.plot(subjects, list(accuracy_wrist_xgb.values()), marker='s', label='XGBoost - Wrist')

# Titles and labels
plt.title('Accuracy Comparison on Binary Classification')
plt.xlabel('Subject')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for chest and wrist accuracies
chest_accuracies_2 = {
    'S2': 0.539, 'S3': 0.550, 'S4': 0.535, 'S5': 0.165, 'S6': 0.662, 'S7': 0.291,
    'S8': 0.529, 'S9': 0.463, 'S10': 0.518, 'S11': 0.793, 'S13': 0.723, 'S14': 0.387,
    'S15': 0.860, 'S16': 0.743, 'S17': 0.837
}

wrist_accuracies_2 = {
    'S2': 0.509, 'S3': 0.546, 'S4': 0.745, 'S5': 0.795, 'S6': 0.366, 'S7': 0.680,
    'S8': 0.730, 'S9': 0.695, 'S10': 0.729, 'S11': 0.538, 'S13': 0.534, 'S14': 0.407,
    'S15': 0.422, 'S16': 0.303, 'S17': 0.701
}

# Second pair of models
chest_accuracies_3 = {
    'S2': 0.537, 'S3': 0.293, 'S4': 0.696, 'S5': 0.662, 'S6': 0.711, 'S7': 0.291,
    'S8': 0.471, 'S9': 0.812, 'S10': 0.518, 'S11': 0.346, 'S13': 0.616, 'S14': 0.307,
    'S15': 0.833, 'S16': 0.719, 'S17': 0.717
}

wrist_accuracies_3 = {
    'S2': 0.510, 'S3': 0.477, 'S4': 0.788, 'S5': 0.705, 'S6': 0.527, 'S7': 0.649,
    'S8': 0.709, 'S9': 0.766, 'S10': 0.675, 'S11': 0.714, 'S13': 0.530, 'S14': 0.530,
    'S15': 0.458, 'S16': 0.339, 'S17': 0.705
}

# Subjects
subjects = list(chest_accuracies_2.keys())

# Plotting the data
plt.figure(figsize=(14, 8))
plt.plot(subjects, list(chest_accuracies_2.values()), label='Decision Tree - Chest', marker='o', color='blue')
plt.plot(subjects, list(wrist_accuracies_2.values()), label='Decision Tree - Wrist', marker='o', color='green')
plt.plot(subjects, list(chest_accuracies_3.values()), label='XGBoost - Chest', marker='s', color='orange')
plt.plot(subjects, list(wrist_accuracies_3.values()), label='XGBoost - Wrist', marker='s', color='red')

# Adding titles and labels
plt.title('Accuracy Comparison on Multiclass Classification')
plt.xlabel('Subjects')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Data for the bar graph
labels = [
    "Decision Tree, Optuna, Full Dataset, Binary",
    "XGBoost, No Tuning, Full Dataset, Binary",
    "XGBoost, No Tuning, Full Dataset, Multi-Class",
    "LSTM, Optuna, 25%, Binary",
    "XGBoost, Optuna, 25%, Binary",
    "Decision Tree, Optuna, 25%, Binary"
]
training_times = [30192, 2993.51, 9512.79, 52000, 17000, 10000]  # in seconds

# Plotting the bar graph
plt.figure(figsize=(12, 6))
plt.barh(labels, training_times, color=['skyblue', 'orange', 'green', 'red', 'purple', 'blue'])
plt.xlabel("Training Time (seconds)")
plt.title("Training Time (Both Modalities) for Various Models")
plt.gca().invert_yaxis()  # to make the highest time appear at the top
plt.show()
